# %% [markdown]
# # Loading data

# %%
import pandas as pd
df = pd.read_csv("fraud.csv")

# %% [markdown]
# ## Cleaning data
#
# These data are mostly clean but we need to add a new field for transaction interarrival time.  Unlike the rest of the work in this notebook, we'll do this for *all* our data (i.e., we'll do this before holding out a test set).

# %%
df = df.sort_values(["user_id", "timestamp"]).reset_index()
del df['index']

# %%
shifted = df.shift(1)[['user_id', 'timestamp']]

df['prev_user_id'] = shifted['user_id']
df['prev_timestamp'] = shifted['timestamp']
df['interarrival'] = (df['timestamp'] - df['prev_timestamp']).where(df['user_id'] == df['prev_user_id'], np.NaN)

del df['prev_user_id']
del df['prev_timestamp']

# %%
df
# Out:
#            timestamp       label  user_id  amount  merchant_id    trans_type  \
# 0         1581668911  legitimate        0   21.95        18943  chip_and_pin
# 1         1581678337  legitimate        0   13.06        12373        online
# 2         1581687106  legitimate        0   85.17         2235        online
# 3         1581695596  legitimate        0   12.73         3257        manual
# 4         1581704538  legitimate        0   84.85        12362  chip_and_pin
# ...              ...         ...      ...     ...          ...           ...
# 22946126  1614976094  legitimate     9999   22.44         1320         swipe
# 22946127  1614987532  legitimate     9999   23.70        17415  chip_and_pin
# 22946128  1614997523  legitimate     9999   30.30         9948   contactless
# 22946129  1615007360  legitimate     9999   29.45         8417         swipe
# 22946130  1615017556  legitimate     9999   25.47        16677   contactless
#
#           foreign  prev_user_id  prev_timestamp  interarrival
# 0           False           NaN             NaN           NaN
# 1           False           0.0    1.581669e+09        9426.0
# 2           False           0.0    1.581678e+09        8769.0
# 3           False           0.0    1.581687e+09        8490.0
# 4           False           0.0    1.581696e+09        8942.0
# ...           ...           ...             ...           ...
# 22946126    False        9999.0    1.614931e+09       44815.0
# 22946127    False        9999.0    1.614976e+09       11438.0
# 22946128    False        9999.0    1.614988e+09        9991.0
# 22946129    False        9999.0    1.614998e+09        9837.0
# 22946130    False        9999.0    1.615007e+09       10196.0
#
# [22946131 rows x 10 columns]

# %% [markdown]
# ##  Train/test split
#
# We're using time-series data, so we'll split based on time.

# %%
first = df['timestamp'].min()
last = df['timestamp'].max()
cutoff = first + ((last - first) * 0.7)

# %%
train = df[df['timestamp'] <= cutoff]
len(train)
# Out:
# 16055561

# %%
test = df[df['timestamp'] > cutoff]
len(test)
# Out:
# 6890570

# %%
len(train) / (len(train) + len(test))
# Out:
# 0.6997066738614889
